# %%
import numpy as np
from keras.models import Sequential
from keras.layers import *
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.optimizers import *
from keras.models import load_model
import matplotlib.pyplot as plt
from music21 import chord, instrument, converter, note, stream
import glob
from tensorflow.keras.utils import to_categorical
from keras.layers import BatchNormalization as BatchNorm
import time
import random

print("DONE")
# Out:
# DONE

# %%
# colab
from google.colab import drive
drive.mount('/content/drive')

# %%
notes = []
start_time = time.time()
for file in glob.glob("dane_treningowe/midi_all/*.mid"):
    midi = converter.parse(file)
    parts = instrument.partitionByInstrument(midi)

    if parts:
        for part in parts:
            if part.getInstrument() is not None:
                instrument_name = part.getInstrument().instrumentName
                if instrument_name == "Acoustic Guitar":
                    notes_to_parse = part.recurse()
                    chord_notes = []
                    for element in notes_to_parse:
                        if isinstance(element, note.Note):
                            notes.append(str(element.pitch))
                        elif isinstance(element, chord.Chord):
                            chord_notes = [str(n) for n in element.normalOrder]
                            chord_str = '.'.join(chord_notes)
                            notes.append(chord_str)

with open("midi_all.txt", "w") as file:
    for note_item in notes:
        file.write(note_item + " ")
end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time_minutes = elapsed_time / 60
print(f"Czas wykonywania programu: {elapsed_time_minutes} minut")
print("DONE")

# %%
notes = []
data1 = []
with open('drive/MyDrive/Praca_inzynierska/mala_baza.txt', 'r') as file:
    data = file.read().split()

for item in data:
    data1.append(item)

lm = int(0.05 * len(data1))

for item in range(lm):
    notes.append(data1[item])



print("DONE")
# Out:
# DONE

# %%
print(notes[100:1000])
# Out:
# ['F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'G2', '7.11.2', 'G2', '7.11.2', 'G2', '7.11.2', '7.11.2', '7.11.2', 'G2', '7.11.2', '7.11.2', '7.11.2', 'C2', '0.4.7', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', '0.4.7', 'C2', '0.4.7', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'D2', '2.5.9', 'D2', '2.5.9', 'D2', '2.5.9', '2.5.9', 'D2', '2.5.9', '2.5.9', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'C2', '0.4.7', '0.4.7', 'C2', '8.1', 'D2', '2.5.9', 'D2', '2.5.9', 'D2', '2.5.9', '2.5.9', 'D2', '2.5.9', '2.5.9', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'D2', '2.5.9', 'D2', '2.5.9', 'D2', '2.5.9', '2.5.9', 'D2', '2.5.9', '2.5.9', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'G2', '7.11.2', 'G2', '7.11.2', 'G2', '7.11.2', '7.11.2', '7.11.2', 'G2', '7.11.2', '7.11.2', '7.11.2', 'C2', '0.4.7', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', '0.4.7', 'C2', '0.4.7', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'D2', '2.5.9', 'D2', '2.5.9', 'D2', '2.5.9', '2.5.9', 'D2', '2.5.9', '2.5.9', 'B-1', '10.2.5', 'B-1', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'B-1', '10.2.5', '10.2.5', 'F2', '5.9.0', 'F2', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'F2', '5.9.0', '5.9.0', '5.9.0', 'C2', '0.4.7', 'C2', '0.4.7', '0.4.7', 'C2', '0.4.7', '0.4.7', 'C2', '8.1', 'D2', '2.5.9', 'D2', '2.5.9', 'D2', '2.5.9', '2.5.9', 'D2', '2.5.9', '2.5.9', 'B-1', '10.2.5', 'B- ...

# %%
pitchnames = sorted(set(item for item in notes)) # zbiór unikalnych akordów i nut
n_vocab = len(pitchnames) #ilosc unikalnych nut i akordów
#słownik, przypisanie nutom ich odpowiednich liczb
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
print("DONE")
# Out:
# DONE

# %%
#wejscia i wyjścia sieci
network_input = []
network_output = []
network = []
seq = 10 # dlugosc sekwencji wejsciowej 10,25,50,100
sequence_length = seq + 1

for i in range(0, len(notes) - sequence_length):
    sequence = notes[i:i + sequence_length]
    network.append(sequence)

# random.shuffle(network)

for j in range(len(network)):
    sequence_in = network[j][:(sequence_length - 1)]
    sequence_out = network[j][sequence_length - 1]
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(note_to_int[sequence_out])
    n_patterns = len(network_input)


print("DONE")
# Out:
# DONE

# %%
data_in = []
data_out = []
network_input = []
network_output = []
network = []
seq = 100 # dlugosc sekwencji wejsciowej 10,25,50,100
sequence_length = seq + 1

with open("drive/MyDrive/Praca_inzynierska/network_input.txt", "w") as file:
    for note_item in network_input:
        file.write(note_item + " ")

with open("drive/MyDrive/Praca_inzynierska/network_output.txt", "w") as file:
    for note_item in network_output:
        file.write(note_item + " ")

notes = []
data1 = []
with open('drive/MyDrive/Praca_inzynierska/network_input.txt', 'r') as file:
    data_in = file.read().split()

for item in data_in:
    network_input.append(item)

with open('drive/MyDrive/Praca_inzynierska/network_output.txt', 'r') as file:
    data_out = file.read().split()

for item in data_out:
    network_output.append(item)

# %%
# normalizacja danych wejściowych
network_input = np.reshape(network_input, (n_patterns, seq, 1))
network_input = network_input / float(n_vocab) # od 0 do 1
network_output = to_categorical(network_output) # one-hot encoding
print("Kształt danych wejściowych (network_input):", network_input.shape)
print("Kształt danych wyjściowych (network_output):", network_output.shape)
# print(network_output)
network_input_train = network_input[: int(0.7*len(network_input))]
network_output_train = network_output[:int(0.7*len(network_output))]

network_input_val = network_input[int(0.7*len(network_input)):int(0.85*len(network_input))]
network_output_val = network_output[int(0.7*len(network_output)):int(0.85*len(network_output))]

network_input_test = network_input[int(0.85*len(network_input)):]
network_output_test = network_output[int(0.85*len(network_output)):]
print("Kształt danych wejściowych treningowych :", network_input_train.shape)
print("Kształt danych wyjściowych treningowych :", network_output_train.shape)
print("Kształt danych wejściowych walidacyjnych :", network_input_val.shape)
print("Kształt danych wyjściowych walidacyjnych :", network_output_val.shape)
print("Kształt danych wejściowych testowych :", network_input_test.shape)
print("Kształt danych wyjściowych testowych :", network_output_test.shape)
# Out:
# Kształt danych wejściowych (network_input): (28926, 10, 1)
# Kształt danych wyjściowych (network_output): (28926, 334)
# Kształt danych wejściowych treningowych : (20248, 10, 1)
# Kształt danych wyjściowych treningowych : (20248, 334)
# Kształt danych wejściowych walidacyjnych : (4339, 10, 1)
# Kształt danych wyjściowych walidacyjnych : (4339, 334)
# Kształt danych wejściowych testowych : (4339, 10, 1)
# Kształt danych wyjściowych testowych : (4339, 334)

# %%
# tworzenie modelu
activation = 'relu'
optimizer = 'rmsprop' # 'rmsprop'Adam
loss='categorical_crossentropy'
num_of_neurons = 512 # 20, 50, 100, 200
num_of_layers = 2
#model = Sequential()
#model.add(LSTM(num_of_neurons, activation=activation, input_shape=(network_input_train.shape[1], network_input_train.shape[2]), return_sequences=True))
#model.add(Dropout(0.2))
#model.add(LSTM(num_of_neurons, activation=activation, return_sequences=False))
#model.add(Dropout(0.2))
#model.add(Dense(n_vocab, activation='softmax'))
model = Sequential()
model.add(LSTM(
    256,
    input_shape=(network_input_train.shape[1], network_input_train.shape[2]),
    recurrent_dropout=0.3,
    return_sequences=True # return sequence instead fo matrix
))
model.add(LSTM(550, return_sequences=True, recurrent_dropout=0.3))
model.add(LSTM(550))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(275))
model.add(Activation('relu'))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(n_vocab))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.summary()
print("DONE")
# Out:
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 10, 256)           264192
#
#  lstm_13 (LSTM)              (None, 10, 550)           1775400
#
#  lstm_14 (LSTM)              (None, 550)               2422200
#
#  batch_normalization_8 (Bat  (None, 550)               2200
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 550)               0
#
#  dense_8 (Dense)             (None, 275)               151525
#
#  activation_8 (Activation)   (None, 275)               0
#
#  batch_normalization_9 (Bat  (None, 275)               1100
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 275)               0
#
#  dense_9 (Dense)             (None, 334)               92184
#
#  activation_9 (Activation)   (None, 334)               0
#
# =================================================================
# Total params: 4708801 (17.96 MB)
# Trainable params: 4707151 (17.96 MB)
# Non-trainable params: 1650 (6.45 KB)
# _________________________________________________________________
# DONE

# %%
# checkpoint - zapisanie najlepszego modelu
epochs = 180
batch_size = 64
#file_name = f'MODEL_GRU_{num_of_neurons}neurons_{epochs}epochs_{batch_size}batchsize_{seq}seq_len_{num_of_layers}_num_of_layers.hdf5'
file_name = "drive/MyDrive/Praca_inzynierska/mod/weights-improvement-79+{epoch:02d}-{loss:.4f}-bigger_drugi_LSTM256_LSTM550_LSTM550_DENSE275.hdf5"
checkpoint = ModelCheckpoint(file_name, save_best_only=True, monitor='loss', verbose=0)
print("DONE")
# Out:
# DONE

# %%
model = load_model("drive/MyDrive/Praca_inzynierska/weights-improvement-79-0.6636-bigger_drugi_LSTM356_LSTM650_LSTM650_DENSE375.hdf5")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# trening
history = model.fit(network_input_train, network_output_train, epochs=epochs, batch_size=batch_size, validation_data=(network_input_val, network_output_val), callbacks=[checkpoint])
print("DONE")
# Out:
# Epoch 1/180
# 317/317 [==============================] - 40s 102ms/step - loss: 5.0279 - accuracy: 0.0513 - val_loss: 4.7792 - val_accuracy: 0.0134
# Epoch 2/180
# 317/317 [==============================] - 31s 97ms/step - loss: 4.3527 - accuracy: 0.0590 - val_loss: 4.2852 - val_accuracy: 0.0567
# Epoch 3/180
# 317/317 [==============================] - 31s 98ms/step - loss: 4.2398 - accuracy: 0.0686 - val_loss: 8.9209 - val_accuracy: 0.0378
# Epoch 4/180
# 317/317 [==============================] - 32s 99ms/step - loss: 4.1720 - accuracy: 0.0796 - val_loss: 4.3021 - val_accuracy: 0.0595
# Epoch 5/180
# 317/317 [==============================] - 32s 100ms/step - loss: 4.0921 - accuracy: 0.0939 - val_loss: 4.1853 - val_accuracy: 0.0862
# Epoch 6/180
# 317/317 [==============================] - 31s 98ms/step - loss: 4.0005 - accuracy: 0.1137 - val_loss: 3.9996 - val_accuracy: 0.1092
# Epoch 7/180
# 317/317 [==============================] - 32s 100ms/step - loss: 3.8820 - accuracy: 0.1297 - val_loss: 3.7934 - val_accuracy: 0.1544
# Epoch 8/180
# 317/317 [==============================] - 32s 100ms/step - loss: 3.7999 - accuracy: 0.1473 - val_loss: 4.1442 - val_accuracy: 0.1337
# Epoch 9/180
# 317/317 [==============================] - 32s 100ms/step - loss: 3.7167 - accuracy: 0.1595 - val_loss: 3.7830 - val_accuracy: 0.1763
# Epoch 10/180
# 317/317 [==============================] - 32s 100ms/step - loss: 3.6360 - accuracy: 0.1804 - val_loss: 3.7045 - val_accuracy: 0.1823
# Epoch 11/180
# 317/317 [==============================] - 32s 101ms/step - loss: 3.5671 - accuracy: 0.1927 - val_loss: 3.5343 - val_accuracy: 0.2021
# Epoch 12/180
# 317/317 [==============================] - 33s 103ms/step - loss: 3.4845 - accuracy: 0.2107 - val_loss: 3.6452 - val_accuracy: 0.1996
# Epoch 13/180
# 317/317 [==============================] - 32s 102ms/step - loss: 3.4070 - accuracy: 0.2207 - val_loss: 3.4331 - val_accuracy: 0.2300
# Epoch 14/180
# 317/317 [==============================] - 32s 101ms/step - loss: 3.3349 - accuracy: 0.2365 - val_loss: 3.4276 - val_accuracy: 0.2319
# Epoch 15/180
# 317/317 [==============================] - 31s 99ms/step - loss: 3.2681 - accuracy: 0.2483 - val_loss: 3.3325 - val_accuracy: 0.2450
# Epoch 16/180
# 317/317 [==============================] - 32s 101ms/step - loss: 3.2001 - accuracy: 0.2573 - val_loss: 3.2227 - val_accuracy: 0.2625
# Epoch 17/180
# 317/317 [==============================] - 32s 99ms/step - loss: 3.1469 - accuracy: 0.2706 - val_loss: 3.2857 - val_accuracy: 0.2466
# Epoch 18/180
# 317/317 [==============================] - 31s 99ms/step - loss: 3.0864 - accuracy: 0.2801 - val_loss: 3.2109 - val_accuracy: 0.2685
# Epoch 19/180
# 317/317 [==============================] - 32s 101ms/step - loss: 3.0362 - accuracy: 0.2921 - val_loss: 3.1378 - val_accuracy: 0.2862
# Epoch 20/180
# 317/317 [==============================] - 32s 100ms/step - loss: 2.9901 - accuracy: 0.2984 - val_loss: 3.1313 - val_accuracy: 0.2789
# Epoch 21/180
# 317/317 [==============================] - 31s 99ms/step - loss: 2.9226 - accuracy: 0.3120 - val_loss: 3.0956 - val_accuracy: 0.2938
# Epoch 22/180
# 317/317 [==============================] - 32s 102ms/step - loss: 2.8646 - accuracy: 0.3240 - val_loss: 3.0147 - val_accuracy: 0.3160
# Epoch 23/180
# 317/317 [==============================] - 32s 100ms/step - loss: 2.8014 - accuracy: 0.3359 - val_loss: 3.2519 - val_accuracy: 0.2789
# Epoch 24/180
# 317/317 [==============================] - 32s 102ms/step - loss: 2.7422 - accuracy: 0.3447 - val_loss: 3.0434 - val_accuracy: 0.3137
# Epoch 25/180
# 317/317 [==============================] - 32s 101ms/step - loss: 2.6921 - accuracy: 0.3583 - val_loss: 2.9824 - val_accuracy: 0.3369
# Epoch 26/180
# 317/317 [==============================] - 32s 101ms/step - loss: 2.6346 - accuracy: 0.3672 - val_loss: 3.0003 - val_accuracy: 0.3284
# Epoch 27/180
# 317/317 [==============================] - 32s 102ms/step - loss: 2.5710 - accuracy: 0.3808 - val_loss: 3.1714 - val_accuracy: 0.3056
# Epoch 28/180
# 317/317 [==============================] - 32s 102ms/step - loss: 2.5172 - accuracy: 0.3924 - val_loss: 2.9529 - val_accuracy: 0.3448
# Epoch 29/180
# 317/317 [==============================] - 32s 102ms/step - loss: 2.4517 - accuracy: 0.4049 - val_loss: 3.1770 - val_accuracy: 0.3268
# Epoch 30/180
# 317/317 [==============================] - 32s 100ms/step - loss: 2.3841 - accuracy: 0.4191 - val_loss: 3.0425 - val_accuracy: 0.3402
# Epoch 31/180
# 317/317 [==============================] - 33s 103ms/step - loss: 2.3408 - accuracy: 0.4284 - val_loss: 2.8682 - val_accuracy: 0.3660
# Epoch 32/180
# 317/317 [==============================] - 32s 102ms/step - loss: 2.2710 - accuracy: 0.4394 - val_loss: 2.8629 - val_accuracy: 0.3734
# Epoch 33/180
# 317/317 [==============================] - 32s 101ms/step - loss: 2.2049 - accuracy: 0.4564 - val_loss: 2.9465 - val_accuracy: 0.3685
# Epoch 34/180
# 317/317 [==============================] - 32s 100ms/step - loss: 2.1483 - accuracy: 0.4643 - val_loss: 2.9245 - val_accuracy: 0.3690
# Epoch 35/180
# 317/317 [==============================] - 32s 101ms/step - loss: 2.0918 - accuracy: 0.4805 - val_loss: 2.9049 - val_accuracy: 0.3826
# Epoch 36/180
# 317/317 [==============================] - 32s 101ms/step - loss: 2.0228 - accuracy: 0.4896 - val_loss: 2.8842 - val_accuracy: 0.3962
# Epoch 37/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.9840 - accuracy: 0.5033 - val_loss: 2.8443 - val_accuracy: 0.4065
# Epoch 38/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.9198 - accuracy: 0.5153 - val_loss: 2.8577 - val_accuracy: 0.4008
# Epoch 39/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.8700 - accuracy: 0.5270 - val_loss: 2.9507 - val_accuracy: 0.3847
# Epoch 40/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.8053 - accuracy: 0.5410 - val_loss: 2.8405 - val_accuracy: 0.4137
# Epoch 41/180
# 317/317 [==============================] - 32s 101ms/step - loss: 1.7592 - accuracy: 0.5473 - val_loss: 2.8711 - val_accuracy: 0.4197
# Epoch 42/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.7108 - accuracy: 0.5561 - val_loss: 2.8320 - val_accuracy: 0.4190
# Epoch 43/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.6421 - accuracy: 0.5746 - val_loss: 2.9407 - val_accuracy: 0.4153
# Epoch 44/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.5985 - accuracy: 0.5835 - val_loss: 2.8561 - val_accuracy: 0.4277
# Epoch 45/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.5578 - accuracy: 0.5905 - val_loss: 3.0008 - val_accuracy: 0.4040
# Epoch 46/180
# 317/317 [==============================] - 32s 101ms/step - loss: 1.5016 - accuracy: 0.6053 - val_loss: 2.8862 - val_accuracy: 0.4245
# Epoch 47/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.4673 - accuracy: 0.6168 - val_loss: 2.9842 - val_accuracy: 0.4167
# Epoch 48/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.4335 - accuracy: 0.6209 - val_loss: 2.8855 - val_accuracy: 0.4377
# Epoch 49/180
# 317/317 [==============================] - 31s 97ms/step - loss: 1.3890 - accuracy: 0.6290 - val_loss: 2.9601 - val_accuracy: 0.4305
# Epoch 50/180
# 317/317 [==============================] - 31s 98ms/step - loss: 1.3448 - accuracy: 0.6457 - val_loss: 2.8874 - val_accuracy: 0.4533
# Epoch 51/180
# 317/317 [==============================] - 31s 96ms/step - loss: 1.3015 - accuracy: 0.6548 - val_loss: 2.9459 - val_accuracy: 0.4409
# Epoch 52/180
# 317/317 [==============================] - 31s 98ms/step - loss: 1.2713 - accuracy: 0.6588 - val_loss: 2.8961 - val_accuracy: 0.4526
# Epoch 53/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.2133 - accuracy: 0.6724 - val_loss: 2.9812 - val_accuracy: 0.4333
# Epoch 54/180
# 317/317 [==============================] - 31s 96ms/step - loss: 1.1838 - accuracy: 0.6849 - val_loss: 2.9686 - val_accuracy: 0.4531
# Epoch 55/180
# 317/317 [==============================] - 31s 99ms/step - loss: 1.1432 - accuracy: 0.6948 - val_loss: 2.9660 - val_accuracy: 0.4609
# Epoch 56/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.1143 - accuracy: 0.6980 - val_loss: 2.9698 - val_accuracy: 0.4533
# Epoch 57/180
# 317/317 [==============================] - 32s 101ms/step - loss: 1.0762 - accuracy: 0.7078 - val_loss: 3.0236 - val_accuracy: 0.4469
# Epoch 58/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.0510 - accuracy: 0.7162 - val_loss: 3.0029 - val_accuracy: 0.4579
# Epoch 59/180
# 317/317 [==============================] - 32s 100ms/step - loss: 1.0245 - accuracy: 0.7198 - val_loss: 3.0219 - val_accuracy: 0.4543
# Epoch 60/180
# 317/317 [==============================] - 33s 103ms/step - loss: 0.9840 - accuracy: 0.7308 - val_loss: 3.0614 - val_accuracy: 0.4559
# Epoch 61/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.9582 - accuracy: 0.7387 - val_loss: 3.1310 - val_accuracy: 0.4457
# Epoch 62/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.9220 - accuracy: 0.7474 - val_loss: 3.1093 - val_accuracy: 0.4665
# Epoch 63/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.9071 - accuracy: 0.7484 - val_loss: 3.0465 - val_accuracy: 0.4658
# Epoch 64/180
# 317/317 [==============================] - 31s 98ms/step - loss: 0.8586 - accuracy: 0.7651 - val_loss: 3.0766 - val_accuracy: 0.4720
# Epoch 65/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.8523 - accuracy: 0.7631 - val_loss: 3.0865 - val_accuracy: 0.4711
# Epoch 66/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.8120 - accuracy: 0.7741 - val_loss: 3.0954 - val_accuracy: 0.4713
# Epoch 67/180
# 317/317 [==============================] - 31s 98ms/step - loss: 0.7997 - accuracy: 0.7791 - val_loss: 3.0890 - val_accuracy: 0.4757
# Epoch 68/180
# 317/317 [==============================] - 33s 103ms/step - loss: 0.7645 - accuracy: 0.7859 - val_loss: 3.1718 - val_accuracy: 0.4697
# Epoch 69/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.7408 - accuracy: 0.7904 - val_loss: 3.1340 - val_accuracy: 0.4824
# Epoch 70/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.7288 - accuracy: 0.7972 - val_loss: 3.1149 - val_accuracy: 0.4842
# Epoch 71/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.7155 - accuracy: 0.7991 - val_loss: 3.1710 - val_accuracy: 0.4847
# Epoch 72/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.6944 - accuracy: 0.8021 - val_loss: 3.1798 - val_accuracy: 0.4785
# Epoch 73/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.6779 - accuracy: 0.8075 - val_loss: 3.2090 - val_accuracy: 0.4831
# Epoch 74/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.6597 - accuracy: 0.8135 - val_loss: 3.2140 - val_accuracy: 0.4902
# Epoch 75/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.6458 - accuracy: 0.8153 - val_loss: 3.2637 - val_accuracy: 0.4757
# Epoch 76/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.6155 - accuracy: 0.8252 - val_loss: 3.2837 - val_accuracy: 0.4771
# Epoch 77/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.6039 - accuracy: 0.8266 - val_loss: 3.2874 - val_accuracy: 0.4787
# Epoch 78/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.5827 - accuracy: 0.8336 - val_loss: 3.3131 - val_accuracy: 0.4902
# Epoch 79/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.5878 - accuracy: 0.8305 - val_loss: 3.3037 - val_accuracy: 0.4757
# Epoch 80/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.5634 - accuracy: 0.8367 - val_loss: 3.2770 - val_accuracy: 0.4840
# Epoch 81/180
# 317/317 [==============================] - 32s 103ms/step - loss: 0.5375 - accuracy: 0.8464 - val_loss: 3.3207 - val_accuracy: 0.4920
# Epoch 82/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.5340 - accuracy: 0.8477 - val_loss: 3.2998 - val_accuracy: 0.4874
# Epoch 83/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.5095 - accuracy: 0.8528 - val_loss: 3.3719 - val_accuracy: 0.4861
# Epoch 84/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.5107 - accuracy: 0.8544 - val_loss: 3.3461 - val_accuracy: 0.4914
# Epoch 85/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.4940 - accuracy: 0.8574 - val_loss: 3.2989 - val_accuracy: 0.4909
# Epoch 86/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.4816 - accuracy: 0.8613 - val_loss: 3.3707 - val_accuracy: 0.4918
# Epoch 87/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.4789 - accuracy: 0.8606 - val_loss: 3.3619 - val_accuracy: 0.4881
# Epoch 88/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.4556 - accuracy: 0.8675 - val_loss: 3.4542 - val_accuracy: 0.4715
# Epoch 89/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.4505 - accuracy: 0.8698 - val_loss: 3.3989 - val_accuracy: 0.4932
# Epoch 90/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.4416 - accuracy: 0.8725 - val_loss: 3.4815 - val_accuracy: 0.4812
# Epoch 91/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.4344 - accuracy: 0.8728 - val_loss: 3.4270 - val_accuracy: 0.4798
# Epoch 92/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.4250 - accuracy: 0.8750 - val_loss: 3.4154 - val_accuracy: 0.4948
# Epoch 93/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.4153 - accuracy: 0.8806 - val_loss: 3.4333 - val_accuracy: 0.4927
# Epoch 94/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.4114 - accuracy: 0.8810 - val_loss: 3.4417 - val_accuracy: 0.4941
# Epoch 95/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.3940 - accuracy: 0.8858 - val_loss: 3.5507 - val_accuracy: 0.4831
# Epoch 96/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.3941 - accuracy: 0.8837 - val_loss: 3.4756 - val_accuracy: 0.4738
# Epoch 97/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.3893 - accuracy: 0.8861 - val_loss: 3.4566 - val_accuracy: 0.4985
# Epoch 98/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.3721 - accuracy: 0.8912 - val_loss: 3.4638 - val_accuracy: 0.4946
# Epoch 99/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.3770 - accuracy: 0.8902 - val_loss: 3.5141 - val_accuracy: 0.4914
# Epoch 100/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.3705 - accuracy: 0.8926 - val_loss: 3.4811 - val_accuracy: 0.4953
# Epoch 101/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.3626 - accuracy: 0.8917 - val_loss: 3.5113 - val_accuracy: 0.4960
# Epoch 102/180
# 317/317 [==============================] - 33s 103ms/step - loss: 0.3559 - accuracy: 0.8944 - val_loss: 3.5687 - val_accuracy: 0.4944
# Epoch 103/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.3565 - accuracy: 0.8947 - val_loss: 3.5416 - val_accuracy: 0.4914
# Epoch 104/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.3535 - accuracy: 0.8963 - val_loss: 3.5643 - val_accuracy: 0.4824
# Epoch 105/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.3489 - accuracy: 0.8964 - val_loss: 3.5604 - val_accuracy: 0.4960
# Epoch 106/180
# 317/317 [==============================] - 32s 101ms/step - loss: 0.3422 - accuracy: 0.9017 - val_loss: 3.4926 - val_accuracy: 0.4969
# Epoch 107/180
# 317/317 [==============================] - 31s 98ms/step - loss: 0.3332 - accuracy: 0.9015 - val_loss: 3.4890 - val_accuracy: 0.4833
# Epoch 108/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.3321 - accuracy: 0.9021 - val_loss: 3.5180 - val_accuracy: 0.4990
# Epoch 109/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.3230 - accuracy: 0.9049 - val_loss: 3.5377 - val_accuracy: 0.4916
# Epoch 110/180
# 317/317 [==============================] - 32s 99ms/step - loss: 0.3176 - accuracy: 0.9054 - val_loss: 3.5529 - val_accuracy: 0.5008
# Epoch 111/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.3103 - accuracy: 0.9068 - val_loss: 3.4980 - val_accuracy: 0.5003
# Epoch 112/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.3223 - accuracy: 0.9064 - val_loss: 3.5156 - val_accuracy: 0.4983
# Epoch 113/180
# 317/317 [==============================] - 32s 99ms/step - loss: 0.3113 - accuracy: 0.9099 - val_loss: 3.5404 - val_accuracy: 0.4976
# Epoch 114/180
# 317/317 [==============================] - 34s 106ms/step - loss: 0.3066 - accuracy: 0.9099 - val_loss: 3.5279 - val_accuracy: 0.4973
# Epoch 115/180
# 317/317 [==============================] - 37s 118ms/step - loss: 0.3088 - accuracy: 0.9106 - val_loss: 3.5327 - val_accuracy: 0.4918
# Epoch 116/180
# 317/317 [==============================] - 37s 117ms/step - loss: 0.3011 - accuracy: 0.9131 - val_loss: 3.5805 - val_accuracy: 0.4983
# Epoch 117/180
# 317/317 [==============================] - 34s 107ms/step - loss: 0.2910 - accuracy: 0.9153 - val_loss: 3.5163 - val_accuracy: 0.4962
# Epoch 118/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2977 - accuracy: 0.9114 - val_loss: 3.5886 - val_accuracy: 0.4992
# Epoch 119/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2907 - accuracy: 0.9154 - val_loss: 3.6657 - val_accuracy: 0.4888
# Epoch 120/180
# 317/317 [==============================] - 35s 109ms/step - loss: 0.2864 - accuracy: 0.9160 - val_loss: 3.5754 - val_accuracy: 0.4985
# Epoch 121/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2872 - accuracy: 0.9165 - val_loss: 3.6306 - val_accuracy: 0.4967
# Epoch 122/180
# 317/317 [==============================] - 32s 99ms/step - loss: 0.2852 - accuracy: 0.9171 - val_loss: 3.6149 - val_accuracy: 0.4994
# Epoch 123/180
# 317/317 [==============================] - 40s 126ms/step - loss: 0.2822 - accuracy: 0.9161 - val_loss: 3.6069 - val_accuracy: 0.4925
# Epoch 124/180
# 317/317 [==============================] - 34s 107ms/step - loss: 0.2860 - accuracy: 0.9172 - val_loss: 3.6467 - val_accuracy: 0.4964
# Epoch 125/180
# 317/317 [==============================] - 41s 131ms/step - loss: 0.2721 - accuracy: 0.9187 - val_loss: 3.6209 - val_accuracy: 0.4967
# Epoch 126/180
# 317/317 [==============================] - 39s 123ms/step - loss: 0.2742 - accuracy: 0.9205 - val_loss: 3.6792 - val_accuracy: 0.4969
# Epoch 127/180
# 317/317 [==============================] - 34s 106ms/step - loss: 0.2760 - accuracy: 0.9198 - val_loss: 3.6735 - val_accuracy: 0.4955
# Epoch 128/180
# 317/317 [==============================] - 38s 120ms/step - loss: 0.2741 - accuracy: 0.9194 - val_loss: 3.6504 - val_accuracy: 0.5027
# Epoch 129/180
# 317/317 [==============================] - 37s 117ms/step - loss: 0.2640 - accuracy: 0.9222 - val_loss: 3.6274 - val_accuracy: 0.5008
# Epoch 130/180
# 317/317 [==============================] - 37s 116ms/step - loss: 0.2645 - accuracy: 0.9238 - val_loss: 3.6106 - val_accuracy: 0.4976
# Epoch 131/180
# 317/317 [==============================] - 34s 108ms/step - loss: 0.2661 - accuracy: 0.9220 - val_loss: 3.6377 - val_accuracy: 0.4985
# Epoch 132/180
# 317/317 [==============================] - 33s 104ms/step - loss: 0.2642 - accuracy: 0.9237 - val_loss: 3.6831 - val_accuracy: 0.4955
# Epoch 133/180
# 317/317 [==============================] - 33s 103ms/step - loss: 0.2536 - accuracy: 0.9264 - val_loss: 3.6444 - val_accuracy: 0.5024
# Epoch 134/180
# 317/317 [==============================] - 34s 108ms/step - loss: 0.2637 - accuracy: 0.9231 - val_loss: 3.6635 - val_accuracy: 0.4911
# Epoch 135/180
# 317/317 [==============================] - 43s 136ms/step - loss: 0.2582 - accuracy: 0.9244 - val_loss: 3.6719 - val_accuracy: 0.5054
# Epoch 136/180
# 317/317 [==============================] - 31s 96ms/step - loss: 0.2500 - accuracy: 0.9282 - val_loss: 3.6965 - val_accuracy: 0.4980
# Epoch 137/180
# 317/317 [==============================] - 34s 106ms/step - loss: 0.2549 - accuracy: 0.9236 - val_loss: 3.7395 - val_accuracy: 0.5031
# Epoch 138/180
# 317/317 [==============================] - 43s 136ms/step - loss: 0.2506 - accuracy: 0.9274 - val_loss: 3.6608 - val_accuracy: 0.5001
# Epoch 139/180
# 317/317 [==============================] - 45s 141ms/step - loss: 0.2537 - accuracy: 0.9264 - val_loss: 3.7203 - val_accuracy: 0.4969
# Epoch 140/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2498 - accuracy: 0.9265 - val_loss: 3.6431 - val_accuracy: 0.4990
# Epoch 141/180
# 317/317 [==============================] - 34s 106ms/step - loss: 0.2469 - accuracy: 0.9284 - val_loss: 3.7641 - val_accuracy: 0.4897
# Epoch 142/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2486 - accuracy: 0.9281 - val_loss: 3.7449 - val_accuracy: 0.4950
# Epoch 143/180
# 317/317 [==============================] - 32s 102ms/step - loss: 0.2504 - accuracy: 0.9259 - val_loss: 3.7276 - val_accuracy: 0.4976
# Epoch 144/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.2463 - accuracy: 0.9281 - val_loss: 3.7004 - val_accuracy: 0.5024
# Epoch 145/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.2398 - accuracy: 0.9289 - val_loss: 3.7787 - val_accuracy: 0.4941
# Epoch 146/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.2411 - accuracy: 0.9286 - val_loss: 3.7045 - val_accuracy: 0.5068
# Epoch 147/180
# 317/317 [==============================] - 31s 98ms/step - loss: 0.2390 - accuracy: 0.9296 - val_loss: 3.7445 - val_accuracy: 0.4950
# Epoch 148/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.2336 - accuracy: 0.9329 - val_loss: 3.7542 - val_accuracy: 0.5024
# Epoch 149/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.2326 - accuracy: 0.9320 - val_loss: 3.7719 - val_accuracy: 0.4992
# Epoch 150/180
# 317/317 [==============================] - 31s 97ms/step - loss: 0.2339 - accuracy: 0.9303 - val_loss: 3.7698 - val_accuracy: 0.5029
# Epoch 151/180
# 317/317 [==============================] - 30s 96ms/step - loss: 0.2366 - accuracy: 0.9309 - val_loss: 3.7929 - val_accuracy: 0.4985
# Epoch 152/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2438 - accuracy: 0.9283 - val_loss: 3.7306 - val_accuracy: 0.5010
# Epoch 153/180
# 317/317 [==============================] - 31s 97ms/step - loss: 0.2354 - accuracy: 0.9305 - val_loss: 3.7627 - val_accuracy: 0.4957
# Epoch 154/180
# 317/317 [==============================] - 38s 119ms/step - loss: 0.2259 - accuracy: 0.9342 - val_loss: 3.7327 - val_accuracy: 0.4785
# Epoch 155/180
# 317/317 [==============================] - 31s 99ms/step - loss: 0.2290 - accuracy: 0.9328 - val_loss: 3.8377 - val_accuracy: 0.4925
# Epoch 156/180
# 317/317 [==============================] - 32s 100ms/step - loss: 0.2284 - accuracy: 0.9330 - val_loss: 3.7744 - val_accuracy: 0.5024
# Epoch 157/180
# 313/317 [============================>.] - ETA: 0s - loss: 0.2307 - accuracy: 0.9329

# %%
#loaded_model = load_model('MODEL_2lstm_25neurons_25epochs_100batchsize_seq100.hdf5')

#try:
#    history = loaded_model.history
#except AttributeError:
#    print("Model nie posiada historii trenowania.")
#    history = None

if history is not None:
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Wykres val_accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title('Model Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Validation Accuracy')
    plt.legend(loc='lower right')

    plt.show()
else:
    print("Brak dostępnej historii trenowania.")

# %%
model = load_model("models/MODEL_200neurons_120epochs_100batchsize_10seq_len_2_num_of_layers.hdf5")
print("DONEE")
# Out:
# DONEE

# %%
# generowanie nowych nut
number_of_notes = 100
start = np.random.randint(0, len(network_input_train) - sequence_length - 1)
#start = 11
int_to_note = dict((number, note) for number, note in enumerate(pitchnames))
pattern = network_input_train[start]
tr = network_input_train[start:start + number_of_notes]
train = []
prediction_output = []
for note_index in range(number_of_notes):
    prediction_input = np.reshape(pattern, (1, len(pattern), 1)) # normalizacja
    prediction = model.predict(prediction_input, verbose=0)
    index = np.argmax(prediction)
    pattern = np.append(pattern, index)
    pattern = pattern[1:]
    result = int_to_note[index]
    prediction_output.append(result)
    train.append(int_to_note[tr[start+note_index]])

print(train)
print(len(train))
print("DONE")
print("______________________")
print(prediction_output)
print(len(prediction_output))
print("______________________")
# Out:
# DONE
# ______________________
# ['B2', '7.11.2', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'D4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'D4', 'D4', 'D4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'G3', 'G3', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'G3', '7', 'B4', 'B4', 'G3', 'G3', 'B4', 'D3', 'C4', 'G4', 'G4']
# 100
# ______________________

# %%
print(prediction_output)

# %%
# tworzenie nut i akordów dla nowych danych
offset = 0  # przesuniecie nut lub akordów (czas)
output_notes = []

for item in prediction_output:
    # szukanie akordów
    if ('.' in item) or item.isdigit():
        notes_in_chord = item.split('.')
      #  print(notes_in_chord)
        notes12 = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))
            new_note.storedInstrument = instrument.AcousticGuitar()
            notes12.append(new_note)
        new_chord = chord.Chord(notes12)
        new_chord.offset = offset
        output_notes.append(new_chord)
    # nuta
    else:
          #   print(item)
        new_note = note.Note(item)
        new_note.offset = offset
        new_note.storedInstrument = instrument.AcousticGuitar()
        output_notes.append(new_note)

    offset += 0.5
       # new_note = note.Note(item)
       # new_note.offset = offset
       # new_note.storedInstrument = instrument.AcousticGuitar()
       # output_notes.append(new_note)



print("DONE")
# Out:
# DONE

# %%
# DLA DANYCH TRENINGOWYCH

offset = 0  # przesuniecie nut lub akordów (czas)
output_notes1 = []

for item in train:
    # szukanie akordów
    if ('.' in item) or item.isdigit():
        notes_in_chord = item.split('.')
      #  print(notes_in_chord)
        notes12 = []
        for current_note in notes_in_chord:
            new_note = note.Note(int(current_note))
            new_note.storedInstrument = instrument.AcousticGuitar()
            notes12.append(new_note)
        new_chord = chord.Chord(notes12)
        new_chord.offset = offset
        output_notes1.append(new_chord)
    # nuta
    else:
          #   print(item)
        new_note = note.Note(item)
        new_note.offset = offset
        new_note.storedInstrument = instrument.AcousticGuitar()
        output_notes1.append(new_note)

    offset += 0.5


offsets1 = []
pitches1 = []

for item in output_notes1:
    if isinstance(item, note.Note):
        offsets1.append(item.offset)
        pitches1.append(item.pitch.midi)
    elif isinstance(item, chord.Chord):
        chord_pitches = [note_in_chord.pitch.midi for note_in_chord in item.notes]
        avg_pitch = sum(chord_pitches) / len(chord_pitches) # dla akordów liczona jest średnia arytmetyczna
        offsets1.append(item.offset)
        pitches1.append(avg_pitch)

plt.figure(figsize=(15, 8))
plt.plot(offsets1, pitches1, marker='o', linestyle='-', color='b')
plt.title('Krzywa tonalna')
plt.xlabel('Czas (offset)')
plt.ylabel('Wysokość tonu ')

# Ustaw zakres osi Y
plt.ylim(50, 80)

file_out = f'trening_MODEL{num_of_neurons}neurons_{epochs}epochs_{batch_size}batchsize_{seq}seq_len_{num_of_layers}_num_of_layers.mid'

midi_stream = stream.Stream()

guitar = instrument.Guitar()
midi_stream.append(guitar)

for item in output_notes1:
    if isinstance(item, note.Note) or isinstance(item, chord.Chord):
        # Ustaw instrument dla każdej nuty i akordu
        item.storedInstrument = guitar
      #  item.offset = offset
        midi_stream.append(item)
        #offset += 0.5

file_out = f'trening_MODEL{num_of_neurons}neurons_{epochs}epochs_{batch_size}batchsize_{seq}seq_len_{num_of_layers}_num_of_layers.mid'
midi_stream.write('midi', fp=file_out)
print("DONE")

# %%
offsets = []
pitches = []

for item in output_notes:
    if isinstance(item, note.Note):
        offsets.append(item.offset)
        pitches.append(item.pitch.midi)
    elif isinstance(item, chord.Chord):
        chord_pitches = [note_in_chord.pitch.midi for note_in_chord in item.notes]
        avg_pitch = sum(chord_pitches) / len(chord_pitches) # dla akordów liczona jest średnia arytmetyczna
        offsets.append(item.offset)
        pitches.append(avg_pitch)

plt.figure(figsize=(15, 8))
plt.plot(offsets, pitches, marker='o', linestyle='-', color='b')
plt.title('Krzywa tonalna')
plt.xlabel('Czas (offset)')
plt.ylabel('Wysokość tonu ')

# Ustaw zakres osi Y
plt.ylim(50, 80)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4717730e7cc3> in <cell line: 4>()
#       2 pitches = []
#       3
# ----> 4 for item in output_notes:
#       5     if isinstance(item, note.Note):
#       6         offsets.append(item.offset)
#
# NameError: name 'output_notes' is not defined

# %%
# tworzenie pliku midi
#offset = 0
file_out = f'MODEL{num_of_neurons}neurons_{epochs}epochs_{batch_size}batchsize_{seq}seq_len_{num_of_layers}_num_of_layers.mid'

midi_stream = stream.Stream()

guitar = instrument.Guitar()
midi_stream.append(guitar)

for item in output_notes:
    if isinstance(item, note.Note) or isinstance(item, chord.Chord):
        # Ustaw instrument dla każdej nuty i akordu
        item.storedInstrument = guitar
      #  item.offset = offset
        midi_stream.append(item)
        #offset += 0.5

file_out = f'MODEL{num_of_neurons}neurons_{epochs}epochs_{batch_size}batchsize_{seq}seq_len_{num_of_layers}_num_of_layers.mid'
midi_stream.write('midi', fp=file_out)
print("DONE")
# Out:
# DONE

# %%
mf = converter.parse(file_out)
mf.show('midi')
# Out:
#         <div id="midiPlayerDiv53240"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv53240_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv53240");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv53240_play, 2000);
#         } else {
#             midiPlayerDiv53240_play();
#         }
#         </script>

# %%
print(prediction_output)
